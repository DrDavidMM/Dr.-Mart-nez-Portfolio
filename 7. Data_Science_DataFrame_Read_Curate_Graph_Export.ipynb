# %%
import pandas as pd

# %%
pd.read_csv("datos_rrss_t1.csv")
# Out:
#       Nombre  Cantidad     ES_FBK  Anio
# 0   Facebook      2449  VERDADERO  2006
# 1    Twitter       339      FALSO  2006
# 2  Instagram      1000  VERDADERO  2010
# 3    YouTube      2000      FALSO  2005
# 4   LinkedIn       663      FALSO  2003
# 5   WhatsApp      1600  VERDADERO  2009

# %%
pd.read_csv("datos_rrss_t2.csv", sep=";")
# Out:
#       Nombre  Cantidad     ES_FBK  Anio
# 0   Facebook      2449  VERDADERO  2006
# 1    Twitter       339      FALSO  2006
# 2  Instagram      1000  VERDADERO  2010

# %%
df_rrss=pd.read_csv("datos_rrss_t3.csv", 
            header=None,
            names=["Nombre", "Cantidad", "ES_FBK", "Anio"])

# %%
df_rrss
# Out:
#       Nombre  Cantidad     ES_FBK  Anio
# 0   Facebook      2449  VERDADERO  2006
# 1    Twitter       339      FALSO  2006
# 2  Instagram      1000  VERDADERO  2010
# 3    YouTube      2000      FALSO  2005
# 4   LinkedIn       663      FALSO  2003
# 5   WhatsApp      1600  VERDADERO  2009

# %%
df_rrss.loc[1, 'Nombre']
# Out:
# 'Twitter'

# %%
df_rrss.iloc[1, 0]
# Out:
# 'Twitter'

# %%
df_rrss['Nombre']
# Out:
# 0     Facebook
# 1      Twitter
# 2    Instagram
# 3      YouTube
# 4     LinkedIn
# 5     WhatsApp
# Name: Nombre, dtype: object

# %%
df_rrss.iloc[4]
# Out:
# Nombre      LinkedIn
# Cantidad         663
# ES_FBK         FALSO
# Anio            2003
# Name: 4, dtype: object

# %%
df_rrss['Cantidad']>1500
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# Name: Cantidad, dtype: bool

# %%
df_rrss[lista_rrss['Cantidad']>1500]
# Out:
#      Nombre  Cantidad     ES_FBK  Anio
# 0  Facebook      2449  VERDADERO  2006
# 3   YouTube      2000      FALSO  2005
# 5  WhatsApp      1600  VERDADERO  2009

# %%
df_rrss.sort_values("Nombre", ascending=True)
# Out:
#       Nombre  Cantidad     ES_FBK  Anio
# 0   Facebook      2449  VERDADERO  2006
# 2  Instagram      1000  VERDADERO  2010
# 4   LinkedIn       663      FALSO  2003
# 1    Twitter       339      FALSO  2006
# 5   WhatsApp      1600  VERDADERO  2009
# 3    YouTube      2000      FALSO  2005

# %%
df_rrss.sort_values("Nombre", ascending=False)
# Out:
#       Nombre  Cantidad     ES_FBK  Anio
# 3    YouTube      2000      FALSO  2005
# 5   WhatsApp      1600  VERDADERO  2009
# 1    Twitter       339      FALSO  2006
# 4   LinkedIn       663      FALSO  2003
# 2  Instagram      1000  VERDADERO  2010
# 0   Facebook      2449  VERDADERO  2006

# %%
df_rrss.sort_values(["Anio", "Cantidad"], ascending=[True, False])
# Out:
#       Nombre  Cantidad     ES_FBK  Anio
# 4   LinkedIn       663      FALSO  2003
# 3    YouTube      2000      FALSO  2005
# 0   Facebook      2449  VERDADERO  2006
# 1    Twitter       339      FALSO  2006
# 5   WhatsApp      1600  VERDADERO  2009
# 2  Instagram      1000  VERDADERO  2010

# %%
tiktokdata = ["Tiktok", 1532, False, 2020]

# %%
lista_rrss = [tiktokdata]

# %%
df2_rrss=pd.DataFrame(lista_rrss,
             columns = ["Nombre", "Cantidad", "ES_FBK", "Anio"])

# %%
df2_rrss
# Out:
#    Nombre  Cantidad  ES_FBK  Anio
# 0  Tiktok      1532   False  2020

# %%
df_rrss.append(df2_rrss)
# Out:
#       Nombre  Cantidad     ES_FBK  Anio
# 0   Facebook      2449  VERDADERO  2006
# 1    Twitter       339      FALSO  2006
# 2  Instagram      1000  VERDADERO  2010
# 3    YouTube      2000      FALSO  2005
# 4   LinkedIn       663      FALSO  2003
# 5   WhatsApp      1600  VERDADERO  2009
# 0     Tiktok      1532      False  2020

# %%
df3_rrss=df_rrss.append(df2_rrss, ignore_index = True)

# %%
df3_rrss
# Out:
#       Nombre  Cantidad     ES_FBK  Anio
# 0   Facebook      2449  VERDADERO  2006
# 1    Twitter       339      FALSO  2006
# 2  Instagram      1000  VERDADERO  2010
# 3    YouTube      2000      FALSO  2005
# 4   LinkedIn       663      FALSO  2003
# 5   WhatsApp      1600  VERDADERO  2009
# 6     Tiktok      1532      False  2020

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df3_rrss["Nombre"], df3_rrss["Cantidad"])
plt.show()

# %%
plt.scatter(df3_rrss["Nombre"], df3_rrss["Cantidad"])
plt.show()

# %%
plt.bar(df3_rrss["Nombre"], df3_rrss["Cantidad"])
plt.show()

# %%
plt.pie(df3_rrss["Cantidad"],
        labels=df3_rrss["Nombre"])
plt.show()

# %%
df3_rrss.to_excel("graf3.xlsx")

# %%
df3_rrss.to_csv("graf3.cvs")
